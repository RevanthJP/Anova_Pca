# %% [markdown]
# # 1) Perform Exploratory Data Analysis [both univariate and multivariate analysis to be performed]. The inferences drawn from this should be properly documented.

# %%
# !pip install factor_analyzer

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salon = pd.read_csv("E:\PGP-DSBA\Advanced Statistics\project_anova_pca\Hair Salon.csv")

# %%
salon.head()
# Out:
#    ID  ProdQual  Ecom  TechSup  CompRes  Advertising  ProdLine  SalesFImage  \
# 0   1       8.5   3.9      2.5      5.9          4.8       4.9          6.0
# 1   2       8.2   2.7      5.1      7.2          3.4       7.9          3.1
# 2   3       9.2   3.4      5.6      5.6          5.4       7.4          5.8
# 3   4       6.4   3.3      7.0      3.7          4.7       4.7          4.5
# 4   5       9.0   3.4      5.2      4.6          2.2       6.0          4.5
#
#    ComPricing  WartyClaim  OrdBilling  DelSpeed  Satisfaction
# 0         6.8         4.7         5.0       3.7           8.2
# 1         5.3         5.5         3.9       4.9           5.7
# 2         4.5         6.2         5.4       4.5           8.9
# 3         8.8         7.0         4.3       3.0           4.8
# 4         6.8         6.1         4.5       3.5           7.1

# %%
salon.shape
# Out:
# (100, 13)

# %%
salon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            100 non-null    int64
#  1   ProdQual      100 non-null    float64
#  2   Ecom          100 non-null    float64
#  3   TechSup       100 non-null    float64
#  4   CompRes       100 non-null    float64
#  5   Advertising   100 non-null    float64
#  6   ProdLine      100 non-null    float64
#  7   SalesFImage   100 non-null    float64
#  8   ComPricing    100 non-null    float64
#  9   WartyClaim    100 non-null    float64
#  10  OrdBilling    100 non-null    float64
#  11  DelSpeed      100 non-null    float64
#  12  Satisfaction  100 non-null    float64
# dtypes: float64(12), int64(1)
# memory usage: 10.3 KB

# %%
salon.describe().T
# Out:
#               count    mean        std  min     25%    50%     75%    max
# ID            100.0  50.500  29.011492  1.0  25.750  50.50  75.250  100.0
# ProdQual      100.0   7.810   1.396279  5.0   6.575   8.00   9.100   10.0
# Ecom          100.0   3.672   0.700516  2.2   3.275   3.60   3.925    5.7
# TechSup       100.0   5.365   1.530457  1.3   4.250   5.40   6.625    8.5
# CompRes       100.0   5.442   1.208403  2.6   4.600   5.45   6.325    7.8
# Advertising   100.0   4.010   1.126943  1.9   3.175   4.00   4.800    6.5
# ProdLine      100.0   5.805   1.315285  2.3   4.700   5.75   6.800    8.4
# SalesFImage   100.0   5.123   1.072320  2.9   4.500   4.90   5.800    8.2
# ComPricing    100.0   6.974   1.545055  3.7   5.875   7.10   8.400    9.9
# WartyClaim    100.0   6.043   0.819738  4.1   5.400   6.10   6.600    8.1
# OrdBilling    100.0   4.278   0.928840  2.0   3.700   4.40   4.800    6.7
# DelSpeed      100.0   3.886   0.734437  1.6   3.400   3.90   4.425    5.5
# ...

# %%
salon.isnull().sum()
# Out:
# ID              0
# ProdQual        0
# Ecom            0
# TechSup         0
# CompRes         0
# Advertising     0
# ProdLine        0
# SalesFImage     0
# ComPricing      0
# WartyClaim      0
# OrdBilling      0
# DelSpeed        0
# Satisfaction    0
# dtype: int64

# %% [markdown]
# ### Univariate analysis

# %%
def univariateAnalysis_numeric(column,nbins):
    print("Description of " + column)
    print("----------------------------------------------------------------------------")
    print(salon[column].describe(),end=' ')
    
    
    plt.figure()
    print("Distribution of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(salon[column], kde=False, color='g');
    plt.show()

# %%
univariateAnalysis_numeric('ProdQual', 20)
# Out:
# Description of ProdQual
# ----------------------------------------------------------------------------
# count    100.000000
# mean       7.810000
# std        1.396279
# min        5.000000
# 25%        6.575000
# 50%        8.000000
# 75%        9.100000
# max       10.000000
# Name: ProdQual, dtype: float64 Distribution of ProdQual
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('Ecom', 20)
# Out:
# Description of Ecom
# ----------------------------------------------------------------------------
# count    100.000000
# mean       3.672000
# std        0.700516
# min        2.200000
# 25%        3.275000
# 50%        3.600000
# 75%        3.925000
# max        5.700000
# Name: Ecom, dtype: float64 Distribution of Ecom
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('TechSup', 20)
# Out:
# Description of TechSup
# ----------------------------------------------------------------------------
# count    100.000000
# mean       5.365000
# std        1.530457
# min        1.300000
# 25%        4.250000
# 50%        5.400000
# 75%        6.625000
# max        8.500000
# Name: TechSup, dtype: float64 Distribution of TechSup
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('CompRes', 20)
# Out:
# Description of CompRes
# ----------------------------------------------------------------------------
# count    100.000000
# mean       5.442000
# std        1.208403
# min        2.600000
# 25%        4.600000
# 50%        5.450000
# 75%        6.325000
# max        7.800000
# Name: CompRes, dtype: float64 Distribution of CompRes
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('Advertising', 20)
# Out:
# Description of Advertising
# ----------------------------------------------------------------------------
# count    100.000000
# mean       4.010000
# std        1.126943
# min        1.900000
# 25%        3.175000
# 50%        4.000000
# 75%        4.800000
# max        6.500000
# Name: Advertising, dtype: float64 Distribution of Advertising
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('ProdLine', 20)
# Out:
# Description of ProdLine
# ----------------------------------------------------------------------------
# count    100.000000
# mean       5.805000
# std        1.315285
# min        2.300000
# 25%        4.700000
# 50%        5.750000
# 75%        6.800000
# max        8.400000
# Name: ProdLine, dtype: float64 Distribution of ProdLine
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('SalesFImage', 20)
# Out:
# Description of SalesFImage
# ----------------------------------------------------------------------------
# count    100.00000
# mean       5.12300
# std        1.07232
# min        2.90000
# 25%        4.50000
# 50%        4.90000
# 75%        5.80000
# max        8.20000
# Name: SalesFImage, dtype: float64 Distribution of SalesFImage
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('ComPricing', 20)
# Out:
# Description of ComPricing
# ----------------------------------------------------------------------------
# count    100.000000
# mean       6.974000
# std        1.545055
# min        3.700000
# 25%        5.875000
# 50%        7.100000
# 75%        8.400000
# max        9.900000
# Name: ComPricing, dtype: float64 Distribution of ComPricing
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('WartyClaim', 20)
# Out:
# Description of WartyClaim
# ----------------------------------------------------------------------------
# count    100.000000
# mean       6.043000
# std        0.819738
# min        4.100000
# 25%        5.400000
# 50%        6.100000
# 75%        6.600000
# max        8.100000
# Name: WartyClaim, dtype: float64 Distribution of WartyClaim
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('OrdBilling', 20)
# Out:
# Description of OrdBilling
# ----------------------------------------------------------------------------
# count    100.00000
# mean       4.27800
# std        0.92884
# min        2.00000
# 25%        3.70000
# 50%        4.40000
# 75%        4.80000
# max        6.70000
# Name: OrdBilling, dtype: float64 Distribution of OrdBilling
# ----------------------------------------------------------------------------

# %%
univariateAnalysis_numeric('DelSpeed', 20)
# Out:
# Description of DelSpeed
# ----------------------------------------------------------------------------
# count    100.000000
# mean       3.886000
# std        0.734437
# min        1.600000
# 25%        3.400000
# 50%        3.900000
# 75%        4.425000
# max        5.500000
# Name: DelSpeed, dtype: float64 Distribution of DelSpeed
# ----------------------------------------------------------------------------

# %%
salon_new = salon.drop('ID', axis=1)

# %%
plt.figure(figsize = (20,7))
salon_new.boxplot();

# %% [markdown]
# Ecom, SalesFImage, OrdBilling and DelSpeed has outliers.

# %%
plt.figure(figsize=(10,7))
sns.pairplot(salon_new);

# %%
salon_new.corr()
# Out:
#               ProdQual      Ecom   TechSup   CompRes  Advertising  ProdLine  \
# ProdQual      1.000000 -0.137163  0.095600  0.106370    -0.053473  0.477493
# Ecom         -0.137163  1.000000  0.000867  0.140179     0.429891 -0.052688
# TechSup       0.095600  0.000867  1.000000  0.096657    -0.062870  0.192625
# CompRes       0.106370  0.140179  0.096657  1.000000     0.196917  0.561417
# Advertising  -0.053473  0.429891 -0.062870  0.196917     1.000000 -0.011551
# ProdLine      0.477493 -0.052688  0.192625  0.561417    -0.011551  1.000000
# SalesFImage  -0.151813  0.791544  0.016991  0.229752     0.542204 -0.061316
# ComPricing   -0.401282  0.229462 -0.270787 -0.127954     0.134217 -0.494948
# WartyClaim    0.088312  0.051898  0.797168  0.140408     0.010792  0.273078
# OrdBilling    0.104303  0.156147  0.080102  0.756869     0.184236  0.424408
# DelSpeed      0.027718  0.191636  0.025441  0.865092     0.275863  0.601850
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(salon_new.corr(), annot=True, cmap='Oranges');

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data = salon_new, x= 'Ecom', y= 'SalesFImage');

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data = salon_new, x= 'TechSup', y= 'WartyClaim');

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data = salon_new, x= 'CompRes', y= 'DelSpeed');

# %% [markdown]
# # 2) Scale the variables and write the inference for using the type of scaling function for this case study.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
salon_scaled = pd.DataFrame(sc.fit_transform(salon_new), columns = salon_new.columns)

# %%
salon_scaled.head(10)
# Out:
#    ProdQual      Ecom   TechSup   CompRes  Advertising  ProdLine  SalesFImage  \
# 0  0.496660  0.327114 -1.881421  0.380922     0.704543 -0.691530     0.821973
# 1  0.280721 -1.394538 -0.174023  1.462141    -0.544014  1.600835    -1.896068
# 2  1.000518 -0.390241  0.154322  0.131410     1.239639  1.218774     0.634522
# 3 -1.014914 -0.533712  1.073690 -1.448834     0.615361 -0.844354    -0.583910
# 4  0.856559 -0.390241 -0.108354 -0.700298    -1.614207  0.149004    -0.583910
# 5 -0.942934 -1.251067 -1.487406 -1.116151    -0.008918 -1.150003    -1.333715
# 6 -0.655015  0.040172 -0.239692 -2.363712    -1.703389 -2.678246     0.259620
# 7 -1.158873 -0.533712 -0.962053 -0.533956     0.526178 -1.684888    -0.021557
# 8 -1.446792 -0.103299 -0.174023  1.046288    -0.276466  0.072592     0.634522
# 9 -1.014914  1.187940 -0.174023  0.547263     0.615361 -0.080233     0.540797
#
#    ComPricing  WartyClaim  OrdBilling  DelSpeed  Satisfaction
# ...

# %%
salon_scaled.drop('Satisfaction', axis=1, inplace = True)

# %%
len(salon_scaled.columns)
# Out:
# 11

# %%
salon_scaled.shape
# Out:
# (100, 11)

# %%
salon_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProdQual     100 non-null    float64
#  1   Ecom         100 non-null    float64
#  2   TechSup      100 non-null    float64
#  3   CompRes      100 non-null    float64
#  4   Advertising  100 non-null    float64
#  5   ProdLine     100 non-null    float64
#  6   SalesFImage  100 non-null    float64
#  7   ComPricing   100 non-null    float64
#  8   WartyClaim   100 non-null    float64
#  9   OrdBilling   100 non-null    float64
#  10  DelSpeed     100 non-null    float64
# dtypes: float64(11)
# memory usage: 8.7 KB

# %%
salon_scaled.describe().T
# Out:
#              count          mean       std       min       25%       50%  \
# ProdQual     100.0  8.744394e-16  1.005038 -2.022630 -0.888949  0.136761
# Ecom         100.0  1.020295e-15  1.005038 -2.111893 -0.569580 -0.103299
# TechSup      100.0  1.015854e-15  1.005038 -2.669451 -0.732211  0.022984
# CompRes      100.0 -1.343370e-16  1.005038 -2.363712 -0.700298  0.006654
# Advertising  100.0 -5.884182e-16  1.005038 -1.881755 -0.744675 -0.008918
# ProdLine     100.0  2.353673e-16  1.005038 -2.678246 -0.844354 -0.042027
# SalesFImage  100.0  6.156187e-16  1.005038 -2.083519 -0.583910 -0.209008
# ComPricing   100.0 -7.016610e-16  1.005038 -2.129693 -0.714885  0.081961
# WartyClaim   100.0 -1.274536e-15  1.005038 -2.382210 -0.788348  0.069885
# OrdBilling   100.0  4.440892e-16  1.005038 -2.464877 -0.625417  0.132008
# DelSpeed     100.0  4.729550e-16  1.005038 -3.128268 -0.665065  0.019158
#
#                   75%       max
# ProdQual     0.928538  1.576356
# ...

# %% [markdown]
# # 3) Comment on the comparison between covariance and the correlation matrix after scaling

# %%
cov = np.cov(salon_scaled.T, bias=True)
print(cov)
# Out:
# [[ 1.00000000e+00 -1.37163217e-01  9.56004542e-02  1.06370001e-01
#   -5.34731340e-02  4.77493413e-01 -1.51812874e-01 -4.01281884e-01
#    8.83123063e-02  1.04303074e-01  2.77180027e-02]
#  [-1.37163217e-01  1.00000000e+00  8.66788720e-04  1.40179261e-01
#    4.29890711e-01 -5.26878383e-02  7.91543711e-01  2.29462401e-01
#    5.18981915e-02  1.56147332e-01  1.91636068e-01]
#  [ 9.56004542e-02  8.66788720e-04  1.00000000e+00  9.66565978e-02
#   -6.28700668e-02  1.92625457e-01  1.69905395e-02 -2.70786682e-01
#    7.97167926e-01  8.01018246e-02  2.54406935e-02]
#  [ 1.06370001e-01  1.40179261e-01  9.66565978e-02  1.00000000e+00
#    1.96916847e-01  5.61416952e-01  2.29751761e-01 -1.27954253e-01
#    1.40408297e-01  7.56868591e-01  8.65091697e-01]
#  [-5.34731340e-02  4.29890711e-01 -6.28700668e-02  1.96916847e-01
#    1.00000000e+00 -1.15508187e-02  5.42203658e-01  1.34216894e-01
#    1.07920743e-02  1.84235594e-01  2.75863083e-01]
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cov, annot=True, xticklabels=salon_scaled.columns, yticklabels=salon_scaled.columns);

# %%
corr_scaled = salon_scaled.corr()
corr_scaled
# Out:
#              ProdQual      Ecom   TechSup   CompRes  Advertising  ProdLine  \
# ProdQual     1.000000 -0.137163  0.095600  0.106370    -0.053473  0.477493
# Ecom        -0.137163  1.000000  0.000867  0.140179     0.429891 -0.052688
# TechSup      0.095600  0.000867  1.000000  0.096657    -0.062870  0.192625
# CompRes      0.106370  0.140179  0.096657  1.000000     0.196917  0.561417
# Advertising -0.053473  0.429891 -0.062870  0.196917     1.000000 -0.011551
# ProdLine     0.477493 -0.052688  0.192625  0.561417    -0.011551  1.000000
# SalesFImage -0.151813  0.791544  0.016991  0.229752     0.542204 -0.061316
# ComPricing  -0.401282  0.229462 -0.270787 -0.127954     0.134217 -0.494948
# WartyClaim   0.088312  0.051898  0.797168  0.140408     0.010792  0.273078
# OrdBilling   0.104303  0.156147  0.080102  0.756869     0.184236  0.424408
# DelSpeed     0.027718  0.191636  0.025441  0.865092     0.275863  0.601850
#
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(corr_scaled, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4) Check the dataset for outliers before and after scaling. Draw your inferences from this exercise.

# %% [markdown]
# - As, we know that only the Ecom, SalesFImage, OrdBilling and DelSpeed has outliers from the previous data exploration done using unscaled data.
# - Let check for the same variables for outliers in the scaled data.

# %%
plt.figure(figsize = (20,7))
salon_scaled.boxplot();

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3 = col.quantile([0.25,0.75])
    IQR = Q3 - Q1  
    lower_range = Q1 -(1.5*IQR)
    upper_range = Q3 +(1.5*IQR)
    return lower_range,upper_range

# %%
remove_outlier(salon_scaled['Ecom'])
# Out:
# (-1.9684219735490895, 1.7618237489200326)

# %%
salon_scaled['Ecom'] = np.where(salon_scaled['Ecom']> 1.7618, salon_scaled['Ecom'].median(), salon_scaled['Ecom'])
salon_scaled['Ecom'] = np.where(salon_scaled['Ecom']< -1.9684, salon_scaled['Ecom'].median(), salon_scaled['Ecom'])

# %%
plt.figure(figsize=(10,7))
salon_scaled['Ecom'].plot(kind='box');

# %%
remove_outlier(salon_scaled['SalesFImage'])
# Out:
# (-2.4115589045325008, 2.4621707120897325)

# %%
salon_scaled['SalesFImage'] = np.where(salon_scaled['SalesFImage']> 2.4621, salon_scaled['SalesFImage'].median(), salon_scaled['SalesFImage'])
salon_scaled['SalesFImage'] = np.where(salon_scaled['SalesFImage']< -2.4115, salon_scaled['SalesFImage'].median(), salon_scaled['SalesFImage'])

# %%
plt.figure(figsize=(10,7))
salon_scaled['SalesFImage'].plot(kind='box');

# %%
remove_outlier(salon_scaled['OrdBilling'])
# Out:
# (-2.4107754363786498, 2.3501814397730834)

# %%
salon_scaled['OrdBilling'] = np.where(salon_scaled['OrdBilling']> 2.3501, salon_scaled['OrdBilling'].median(), salon_scaled['OrdBilling'])
salon_scaled['OrdBilling'] = np.where(salon_scaled['OrdBilling']< -2.4107, salon_scaled['OrdBilling'].median(), salon_scaled['OrdBilling'])

# %%
plt.figure(figsize=(10,7))
salon_scaled['OrdBilling'].plot(kind='box');

# %%
remove_outlier(salon_scaled['DelSpeed'])
# Out:
# (-2.769050993962641, 2.8415786453982834)

# %%
salon_scaled['DelSpeed'] = np.where(salon_scaled['DelSpeed']> 2.8415, salon_scaled['DelSpeed'].median(), salon_scaled['DelSpeed'])
salon_scaled['DelSpeed'] = np.where(salon_scaled['DelSpeed']< -2.7690, salon_scaled['DelSpeed'].median(), salon_scaled['DelSpeed'])

# %%
plt.figure(figsize=(10,7))
salon_scaled['DelSpeed'].plot(kind='box');

# %% [markdown]
# # 5) Build the covariance matrix, eigenvalues and eigenvector.

# %%
cov = np.cov(salon_scaled.T, bias=True)
print(cov)
# Out:
# [[ 1.         -0.09585522  0.09560045  0.10637    -0.05347313  0.47749341
#   -0.0823863  -0.40128188  0.08831231  0.072495   -0.00422567]
#  [-0.09585522  0.47268102 -0.02904684 -0.01188963  0.2040567  -0.11676616
#    0.36529311  0.19943011 -0.01074059  0.08251976  0.02262141]
#  [ 0.09560045 -0.02904684  1.          0.0966566  -0.06287007  0.19262546
#   -0.07809309 -0.27078668  0.79716793  0.10507103  0.05303365]
#  [ 0.10637    -0.01188963  0.0966566   1.          0.19691685  0.56141695
#    0.14636001 -0.12795425  0.1404083   0.58041975  0.81687297]
#  [-0.05347313  0.2040567  -0.06287007  0.19691685  1.         -0.01155082
#    0.45519797  0.13421689  0.01079207  0.10400645  0.22505712]
#  [ 0.47749341 -0.11676616  0.19262546  0.56141695 -0.01155082  1.
#   -0.10224148 -0.4949484   0.27307753  0.29235065  0.53198447]
#  [-0.0823863   0.36529311 -0.07809309  0.14636001  0.45519797 -0.10224148
#    0.78496026  0.34088729  0.00554335  0.11335697  0.18945305]
# ...

# %%
from numpy.linalg import eig
eigen_values, eigen_vectors = np.linalg.eig(cov)

# %%
print('The Eigen values are: ', eigen_values)
# Out:
# The Eigen values are:  [3.03969016 2.16167412 1.50614006 1.03871336 0.63648233 0.42590603
#  0.39890628 0.10400615 0.13491754 0.25156462 0.213473  ]

# %%
print('The Eigen vectors are: ', eigen_vectors)
# Out:
# The Eigen vectors are:  [[-2.20841097e-01  2.60356968e-01 -2.68393865e-01 -5.93655450e-01
#    5.14524114e-01 -2.12993665e-01 -2.88894159e-01 -1.71086405e-01
#   -1.49190628e-01 -1.17861844e-01  6.18387767e-04]
#  [ 3.42194783e-02 -2.32363439e-01  1.71920080e-01 -1.85752874e-01
#    2.41900692e-01  5.50924427e-01  1.61657751e-01 -8.42122241e-02
#   -3.79073853e-01  2.30135785e-01 -5.37454700e-01]
#  [-2.54809209e-01  2.83204612e-01  5.89897418e-01  4.45655361e-02
#    4.02807823e-02 -8.98686273e-02 -4.38634495e-02 -9.80741448e-02
#    3.79511574e-01 -3.59404810e-01 -4.58759262e-01]
#  [-4.60954176e-01 -2.73775416e-01 -1.53581234e-01  2.08264563e-01
#   -2.50967416e-02 -8.15315333e-02 -3.47969520e-02  4.69213564e-01
#   -4.07005022e-01 -4.83864532e-01 -1.31070735e-01]
#  [-7.52243966e-02 -4.08924004e-01  1.74484669e-01 -5.40742689e-01
#   -5.65871125e-01 -2.71847534e-01 -2.54646690e-01  2.45993620e-02
#    8.57446500e-03  1.61818320e-01 -1.35848912e-01]
# ...

# %% [markdown]
# # 6) Write the explicit form of the first PC (in terms of Eigen Vectors)

# %% [markdown]
# Before we proceed further, we need to check the significance of correlation and adequacy of the features using bartlett sphericity test and kmo.

# %% [markdown]
# #### Barlett sphericity test
# - H0 : All the features are significantly correlated.
# - H1 : There is no significant correlationn

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

chi_square_value, p_value = calculate_bartlett_sphericity(salon_scaled)
print(p_value)
# Out:
# 1.037328048625203e-82

# %% [markdown]
# Here, we can reject null hypothesis as p-value is less than 0.05.

# %% [markdown]
# #### kmo
# - In kmo, if measure of sampling adequacy(MSA) is less than 0.5, PCA is not recommended, since no reduction is expected. On the other hand, MSA > 0.7 is expected to provide a considerable reduction in the dimension and extraction of meaningful components.

# %%
from factor_analyzer.factor_analyzer import calculate_kmo

kmo_all, kmo_model = calculate_kmo(salon_scaled)
print(kmo_model)
# Out:
# 0.6384541393476492

# %% [markdown]
# Since MSA is close to 0.7, we can expect a considerable reduction in the dimension and extraction of meaningful components to some extent.

# %% [markdown]
# #### PCA

# %%
len(salon_scaled.columns)
# Out:
# 11

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components= 8, random_state=1)
salon_pca = pca.fit_transform(salon_scaled)
salon_pca.T
# Out:
# array([[ 7.94977064e-01, -1.93917285e+00, -2.23048412e+00,
#          1.44427874e+00,  3.19227104e-01,  2.82837055e+00,
#          5.35208399e+00,  1.81795817e+00, -1.20989504e-01,
#          3.13400770e-01,  1.34735369e-01,  2.51633731e+00,
#         -1.80933573e+00, -1.56078795e+00, -1.15500854e+00,
#         -1.82044604e+00, -6.11926972e-01, -1.38131570e+00,
#          8.10720640e-02, -1.86618499e-01,  1.33721121e+00,
#         -2.47218411e+00, -1.87729241e+00, -1.52211183e+00,
#          6.29190125e-01, -2.34628152e-02, -2.55183614e+00,
#          8.51174799e-01, -1.99560977e+00,  2.12175012e+00,
#         -5.48701606e-01,  9.79175537e-01,  1.30360850e+00,
#          1.05286562e-01,  2.07350276e+00,  1.08936231e+00,
#          1.93163017e-01, -2.51100538e+00,  2.70833004e-01,
#          2.39533677e+00,  1.70325294e+00,  2.97586264e-01,
#         -9.64532968e-01, -1.38785243e+00, -1.65146190e+00,
#         -9.64691760e-01, -1.52198830e+00, -1.54717285e+00,
# ...

# %%
pca.components_
# Out:
# array([[-0.2208411 ,  0.03421948, -0.25480921, -0.46095418, -0.0752244 ,
#         -0.4661341 , -0.01382036,  0.26805312, -0.30017508, -0.33197368,
#         -0.42113771],
#        [-0.26035697,  0.23236344, -0.28320461,  0.27377542,  0.408924  ,
#         -0.11523419,  0.42810954,  0.41224601, -0.21317981,  0.21399349,
#          0.31321318],
#        [ 0.26839386, -0.17192008, -0.58989742,  0.15358123, -0.17448467,
#          0.24662621, -0.21983203, -0.16359439, -0.59117391,  0.01679529,
#          0.1035121 ],
#        [ 0.59365545,  0.18575287, -0.04456554, -0.20826456,  0.54074269,
#          0.12230084,  0.34415402, -0.20516559, -0.02071432, -0.21258444,
#         -0.23279299],
#        [-0.51452411, -0.24190069, -0.04028078,  0.02509674,  0.56587112,
#         -0.00212783, -0.25203568, -0.48851796, -0.0523673 , -0.2157576 ,
#          0.05307059],
#        [ 0.21299366, -0.55092443,  0.08986863,  0.08153153,  0.27184753,
# ...

# %%
pca.explained_variance_
# Out:
# array([3.0703941 , 2.18350922, 1.5213536 , 1.04920541, 0.64291145,
#        0.43020811, 0.40293564, 0.25410568])

# %%
var_exp = pca.explained_variance_ratio_
var_exp
# Out:
# array([0.30668398, 0.21809816, 0.15195925, 0.10479908, 0.06421672,
#        0.04297101, 0.04024692, 0.02538115])

# %% [markdown]
# Observation shows that the first 5 components explains the variance better.

# %% [markdown]
# # 7) Discuss the cumulative values of the eigenvalues. How does it help you to decide on the optimum number of principal components? What do the eigenvectors indicate? Perform PCA and export the data of the Principal Component scores into a data frame.

# %% [markdown]
# Now let us visualize and see the pc using scree plot

# %%
plt.figure(figsize=(12,7))
sns.lineplot(y=var_exp,x=range(1,len(var_exp)+1),marker='o')
plt.xlabel('Number of Components',fontsize=15)
plt.ylabel('Variance Explained',fontsize=15)
plt.title('Scree Plot',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# The scree plot also shows that the first 5 components contains more info

# %%
# Creating pca with 5 components

pca2 = PCA(n_components=5, random_state=1)
salon_pca = pca2.fit_transform(salon_scaled)

# %%
pca2.components_
# Out:
# array([[-0.2208411 ,  0.03421948, -0.25480921, -0.46095418, -0.0752244 ,
#         -0.4661341 , -0.01382036,  0.26805312, -0.30017508, -0.33197368,
#         -0.42113771],
#        [-0.26035697,  0.23236344, -0.28320461,  0.27377542,  0.408924  ,
#         -0.11523419,  0.42810954,  0.41224601, -0.21317981,  0.21399349,
#          0.31321318],
#        [ 0.26839386, -0.17192008, -0.58989742,  0.15358123, -0.17448467,
#          0.24662621, -0.21983203, -0.16359439, -0.59117391,  0.01679529,
#          0.1035121 ],
#        [ 0.59365545,  0.18575287, -0.04456554, -0.20826456,  0.54074269,
#          0.12230084,  0.34415402, -0.20516559, -0.02071432, -0.21258444,
#         -0.23279299],
#        [-0.51452411, -0.24190069, -0.04028078,  0.02509674,  0.56587112,
#         -0.00212783, -0.25203568, -0.48851796, -0.0523673 , -0.2157576 ,
#          0.05307059]])

# %%
pca2.explained_variance_
# Out:
# array([3.0703941 , 2.18350922, 1.5213536 , 1.04920541, 0.64291145])

# %%
exp_var = pca2.explained_variance_ratio_
exp_var
# Out:
# array([0.30668398, 0.21809816, 0.15195925, 0.10479908, 0.06421672])

# %%
pca_salon = pd.DataFrame(pca2.components_, columns=salon_scaled.columns)
pca_salon.head()
# Out:
#    ProdQual      Ecom   TechSup   CompRes  Advertising  ProdLine  SalesFImage  \
# 0 -0.220841  0.034219 -0.254809 -0.460954    -0.075224 -0.466134    -0.013820
# 1 -0.260357  0.232363 -0.283205  0.273775     0.408924 -0.115234     0.428110
# 2  0.268394 -0.171920 -0.589897  0.153581    -0.174485  0.246626    -0.219832
# 3  0.593655  0.185753 -0.044566 -0.208265     0.540743  0.122301     0.344154
# 4 -0.514524 -0.241901 -0.040281  0.025097     0.565871 -0.002128    -0.252036
#
#    ComPricing  WartyClaim  OrdBilling  DelSpeed
# 0    0.268053   -0.300175   -0.331974 -0.421138
# 1    0.412246   -0.213180    0.213993  0.313213
# 2   -0.163594   -0.591174    0.016795  0.103512
# 3   -0.205166   -0.020714   -0.212584 -0.232793
# 4   -0.488518   -0.052367   -0.215758  0.053071

# %%
from matplotlib.patches import Rectangle

fig,ax = plt.subplots(figsize=(22, 10), facecolor='w', edgecolor='k')
ax = sns.heatmap(pca_salon, annot=True, vmax=1.0, vmin=0, cmap='Blues', cbar=False, fmt='.2g', ax=ax,
                 yticklabels=['PC0','PC1','PC2','PC3','PC4'])

column_max = pca_salon.abs().idxmax(axis=0)

for col, variable in enumerate(pca_salon.columns):
    position = pca_salon.index.get_loc(column_max[variable])
    ax.add_patch(Rectangle((col, position),1,1, fill=False, edgecolor='red', lw=3))
